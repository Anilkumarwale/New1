# %%
import pandas as pd

# %%
import json

# %%
df = pd.read_excel("D:\Excel.xlsx")

# %%
df1 = df.to_json()

# %%
df1
# Out:
# '{"Unnamed: 0":{"0":"CELIO SALE REPORT From 01\\/10\\/2022 to 31\\/10\\/2022","1":"SNO.","2":"1","3":"2","4":null,"5":"3","6":"4","7":"5","8":"6","9":"7","10":"8","11":"9","12":"10","13":"11","14":"12","15":"13","16":"14","17":null,"18":"15","19":"16","20":"17","21":"18","22":null,"23":"19","24":"20","25":"21","26":"22","27":"23","28":null,"29":"24","30":"25","31":"26","32":"27","33":"28","34":"29","35":"30","36":"31","37":null,"38":"32","39":"33","40":"34","41":"35","42":"36","43":"37","44":"38","45":"39","46":"40","47":null,"48":"41","49":"42","50":"43","51":"44","52":"45","53":"46","54":"47","55":"48","56":"49","57":null,"58":"50","59":"51","60":"52","61":"53","62":"54","63":"55","64":"56","65":"57","66":"58","67":"59","68":"60","69":"61","70":"62","71":"63","72":"64","73":null,"74":"65","75":"66","76":"67","77":"68","78":"69","79":"70","80":"71","81":"72","82":"73","83":"74","84":"75","85":"76","86":"77","87":"78","88":"79","89":"80","90":null,"91":"81","92":"82","93":"83","94":"
# ...

# %%
a=df.iloc[1]

# %%
a.values
# Out:
# array(['SNO.', 'COMPANY NAME', 'BILL DATE', 'BILL NO.', 'GROUP NAME',
#        'G3 CODE', 'ADDITIONAL ITEM CODE', 'ITEM NAME', 'SHADE NAME',
#        'PACK / SIZE', 'TOTAL QUANTITY', 'GROSS AMOUNT', 'CD', 'TD VALUE',
#        'POINT CARD DISCOUNT', 'SCHEME(RS.)', 'SP. DISCOUNT', 'ADJUSTMENT',
#        'TAX-1(RS)', 'TAX-3(RS)', 'ROUND AMOUNT', 'NET AMOUNT'],
#       dtype=object)

# %%
b=a.values

# %%
dfnew = df[2:]

# %%
dfnew
# Out:
#     Unnamed: 0    Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 2            1  CELIO(CON20)  01/10/2022  GGB-14274
# 3            2  CELIO(CON20)  01/10/2022   GSF-7851
# 4          NaN   Date TOTALS         NaN        NaN
# 5            3  CELIO(CON20)  02/10/2022  GAG-11363
# 6            4  CELIO(CON20)  02/10/2022  GAG-11365
# ..         ...           ...         ...        ...
# 360        NaN   Date TOTALS         NaN        NaN
# 361        331  CELIO(CON20)  31/10/2022  GAG-13882
# 362        332  CELIO(CON20)  31/10/2022  GGC-16090
# 363        NaN   Date TOTALS         NaN        NaN
# 364        NaN  GRAND TOTALS         NaN        NaN
#
#                        Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 2    M10 M. C. F/s Shirt (casual)  AS1972340  8904231533769
# 3    M10 M. C. F/s Shirt (casual)  AS2459943  8905550028172
# 4                             NaN        NaN            NaN
# 5    M10 M. C. F/s Shirt (casual)  AS2459958  8905550023825
# ...

# %%
dfnew.columns = b

# %%
dfnew
# Out:
#     SNO.  COMPANY NAME   BILL DATE   BILL NO.                    GROUP NAME  \
# 2      1  CELIO(CON20)  01/10/2022  GGB-14274  M10 M. C. F/s Shirt (casual)
# 3      2  CELIO(CON20)  01/10/2022   GSF-7851  M10 M. C. F/s Shirt (casual)
# 4    NaN   Date TOTALS         NaN        NaN                           NaN
# 5      3  CELIO(CON20)  02/10/2022  GAG-11363  M10 M. C. F/s Shirt (casual)
# 6      4  CELIO(CON20)  02/10/2022  GAG-11365            M41 M. H/s t-shirt
# ..   ...           ...         ...        ...                           ...
# 360  NaN   Date TOTALS         NaN        NaN                           NaN
# 361  331  CELIO(CON20)  31/10/2022  GAG-13882  M10 M. C. F/s Shirt (casual)
# 362  332  CELIO(CON20)  31/10/2022  GGC-16090        M29 M. Jeans Narrowfit
# 363  NaN   Date TOTALS         NaN        NaN                           NaN
# 364  NaN  GRAND TOTALS         NaN        NaN                           NaN
#
# ...

# %%
dfnew1 = dfnew.reset_index()

# %%
dfnew1.columns
# Out:
# Index(['index', 'SNO.', 'COMPANY NAME', 'BILL DATE', 'BILL NO.', 'GROUP NAME',
#        'G3 CODE', 'ADDITIONAL ITEM CODE', 'ITEM NAME', 'SHADE NAME',
#        'PACK / SIZE', 'TOTAL QUANTITY', 'GROSS AMOUNT', 'CD', 'TD VALUE',
#        'POINT CARD DISCOUNT', 'SCHEME(RS.)', 'SP. DISCOUNT', 'ADJUSTMENT',
#        'TAX-1(RS)', 'TAX-3(RS)', 'ROUND AMOUNT', 'NET AMOUNT'],
#       dtype='object')

# %%
dfnew1
# Out:
#      index SNO.  COMPANY NAME   BILL DATE   BILL NO.  \
# 0        2    1  CELIO(CON20)  01/10/2022  GGB-14274
# 1        3    2  CELIO(CON20)  01/10/2022   GSF-7851
# 2        4  NaN   Date TOTALS         NaN        NaN
# 3        5    3  CELIO(CON20)  02/10/2022  GAG-11363
# 4        6    4  CELIO(CON20)  02/10/2022  GAG-11365
# ..     ...  ...           ...         ...        ...
# 358    360  NaN   Date TOTALS         NaN        NaN
# 359    361  331  CELIO(CON20)  31/10/2022  GAG-13882
# 360    362  332  CELIO(CON20)  31/10/2022  GGC-16090
# 361    363  NaN   Date TOTALS         NaN        NaN
# 362    364  NaN  GRAND TOTALS         NaN        NaN
#
#                        GROUP NAME    G3 CODE ADDITIONAL ITEM CODE  \
# 0    M10 M. C. F/s Shirt (casual)  AS1972340        8904231533769
# 1    M10 M. C. F/s Shirt (casual)  AS2459943        8905550028172
# 2                             NaN        NaN                  NaN
# ...

# %%
dfnew2 = dfnew1.drop(['index', 'SNO.', 'COMPANY NAME'],axis=1)

# %%
dfnew2
# Out:
#       BILL DATE   BILL NO.                    GROUP NAME    G3 CODE  \
# 0    01/10/2022  GGB-14274  M10 M. C. F/s Shirt (casual)  AS1972340
# 1    01/10/2022   GSF-7851  M10 M. C. F/s Shirt (casual)  AS2459943
# 2           NaN        NaN                           NaN        NaN
# 3    02/10/2022  GAG-11363  M10 M. C. F/s Shirt (casual)  AS2459958
# 4    02/10/2022  GAG-11365            M41 M. H/s t-shirt  AS2485159
# ..          ...        ...                           ...        ...
# 358         NaN        NaN                           NaN        NaN
# 359  31/10/2022  GAG-13882  M10 M. C. F/s Shirt (casual)  AS2044723
# 360  31/10/2022  GGC-16090        M29 M. Jeans Narrowfit  AS2293055
# 361         NaN        NaN                           NaN        NaN
# 362         NaN        NaN                           NaN        NaN
#
#     ADDITIONAL ITEM CODE                ITEM NAME   SHADE NAME PACK / SIZE  \
# ...

# %%
z =dfnew2.to_json()

# %%
z
# Out:
# '{"BILL DATE":{"0":"01\\/10\\/2022","1":"01\\/10\\/2022","2":null,"3":"02\\/10\\/2022","4":"02\\/10\\/2022","5":"02\\/10\\/2022","6":"02\\/10\\/2022","7":"02\\/10\\/2022","8":"02\\/10\\/2022","9":"02\\/10\\/2022","10":"02\\/10\\/2022","11":"02\\/10\\/2022","12":"02\\/10\\/2022","13":"02\\/10\\/2022","14":"02\\/10\\/2022","15":null,"16":"03\\/10\\/2022","17":"03\\/10\\/2022","18":"03\\/10\\/2022","19":"03\\/10\\/2022","20":null,"21":"04\\/10\\/2022","22":"04\\/10\\/2022","23":"04\\/10\\/2022","24":"04\\/10\\/2022","25":"04\\/10\\/2022","26":null,"27":"05\\/10\\/2022","28":"05\\/10\\/2022","29":"05\\/10\\/2022","30":"05\\/10\\/2022","31":"05\\/10\\/2022","32":"05\\/10\\/2022","33":"05\\/10\\/2022","34":"05\\/10\\/2022","35":null,"36":"06\\/10\\/2022","37":"06\\/10\\/2022","38":"06\\/10\\/2022","39":"06\\/10\\/2022","40":"06\\/10\\/2022","41":"06\\/10\\/2022","42":"06\\/10\\/2022","43":"06\\/10\\/2022","44":"06\\/10\\/2022","45":null,"46":"07\\/10\\/2022","47":"07\\/10\\/2022","48":"07\
# ...
